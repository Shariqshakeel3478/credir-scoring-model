# %%
# Step 1: Necessary libraries ko import karein
import pandas as pd


try:
    df = pd.read_csv('../dataset/german_credit_data.csv')
except FileNotFoundError:
    print("Dataset not found")


# print(df.head()) # prints 5 rows of dataset

# print(df.shape) # prints number of rows and columns in dataset
# print(df.columns) # prints all column names in array
# print(df.info()) #prints datatypes of all columns


# print(df.isnull()) # check for missing values
# print(df.isnull().sum()) # sum all null values in each column

# print(df.describe()) # check statistics of numerical columns

# print(df.describe(include=['object'])) # categorical columns summary

print(df['target']) #target
# Out:
#           status_account  month_duration  \
# 0                 < 0 DM               6
# 1          0 to < 200 DM              48
# 2    no checking account              12
# 3                 < 0 DM              42
# 4                 < 0 DM              24
# ..                   ...             ...
# 995  no checking account              12
# 996               < 0 DM              30
# 997  no checking account              12
# 998               < 0 DM              45
# 999        0 to < 200 DM              45
#
#                                         credit_history              purpose  \
# 0    critical account/ other credits existing (not ...     radio/television
# 1             existing credits paid back duly till now     radio/television
# 2    critical account/ other credits existing (not ...            education
# 3             existing credits paid back duly till now  furniture/equipment
# 4                      delay in paying off in the past            car (new)
# ...
