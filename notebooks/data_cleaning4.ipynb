# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder 

df = pd.read_csv("../dataset/german_credit_data.csv")
df["target"] = df["target"].map({
    "good": 1,
    "bad": 0
})

categorical_cols = df.select_dtypes(include=['object']).columns
le = LabelEncoder()

for col in categorical_cols:
    df[col] = le.fit_transform(df[col]) #fit_transform => number me convert karke array banadeta hai

df.to_csv("cleaned_credit_data.csv", index=False)
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   status_account           1000 non-null   int64
#  1   month_duration           1000 non-null   int64
#  2   credit_history           1000 non-null   int64
#  3   purpose                  1000 non-null   int64
#  4   credit_amount            1000 non-null   int64
#  5   status_savings           1000 non-null   int64
#  6   years_employment         1000 non-null   int64
#  7   payment_to_income_ratio  1000 non-null   int64
#  8   status_and_sex           1000 non-null   int64
#  9   secondary_obligor        1000 non-null   int64
#  10  residence_since          1000 non-null   int64
#  11  collateral               1000 non-null   int64
#  12  age                      1000 non-null   int64
#  13  other_installment_plans  1000 non-null   int64
# ...
